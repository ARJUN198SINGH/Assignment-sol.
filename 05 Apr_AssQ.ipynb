# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Q1. Import the dataset and examine the variables. Use descriptive statistics and visualizations to
# understand the distribution and relationships between the variables?

# %%
df=pd.read_csv('diabetes.csv')

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# Q2. Preprocess the data by cleaning missing values, removing outliers, and transforming categorical
# variables into dummy variables if necessary.

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
sns.boxplot(df)
# Out:
# <AxesSubplot: >

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# Q3. Split the dataset into a training set and a test set. Use a random seed to ensure reproducibility.

# %%
x=df.iloc[:,:-1]
y=df['Outcome']

# %%
x
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# 764                     0.340   27
# 765                     0.245   30
# 766                     0.349   47
# 767                     0.315   23
#
# [768 rows x 8 columns]

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.33)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DTC=DecisionTreeClassifier()
DTC.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(DTC,filled=True)
# Out:
# [Text(0.6084798177083334, 0.9615384615384616, 'x[1] <= 154.5\ngini = 0.457\nsamples = 514\nvalue = [332, 182]'),
#  Text(0.3185221354166667, 0.8846153846153846, 'x[7] <= 30.5\ngini = 0.382\nsamples = 432\nvalue = [321, 111]'),
#  Text(0.18098958333333334, 0.8076923076923077, 'x[1] <= 127.5\ngini = 0.24\nsamples = 251\nvalue = [216, 35]'),
#  Text(0.1171875, 0.7307692307692307, 'x[5] <= 45.45\ngini = 0.153\nsamples = 203\nvalue = [186, 17]'),
#  Text(0.10677083333333333, 0.6538461538461539, 'x[0] <= 6.5\ngini = 0.13\nsamples = 200\nvalue = [186, 14]'),
#  Text(0.09635416666666667, 0.5769230769230769, 'x[1] <= 104.5\ngini = 0.122\nsamples = 199\nvalue = [186, 13]'),
#  Text(0.041666666666666664, 0.5, 'x[4] <= 156.0\ngini = 0.037\nsamples = 107\nvalue = [105, 2]'),
#  Text(0.020833333333333332, 0.4230769230769231, 'x[3] <= 41.0\ngini = 0.019\nsamples = 104\nvalue = [103, 1]'),
#  Text(0.010416666666666666, 0.34615384615384615, 'gini = 0.0\nsamples = 97\nvalue = [97, 0]'),
#  Text(0.03125, 0.34615384615384615, 'x[4] <= 22.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.020833333333333332, 0.2692307692307692, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.041666666666666664, 0.2692307692307692, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.0625, 0.4230769230769231, 'x[6] <= 0.564\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.052083333333333336, 0.34615384615384615, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.07291666666666667, 0.34615384615384615, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15104166666666666, 0.5, 'x[4] <= 49.0\ngini = 0.211\nsamples = 92\nvalue = [81, 11]'),
#  Text(0.11458333333333333, 0.4230769230769231, 'x[5] <= 31.3\ngini = 0.349\nsamples = 40\nvalue = [31, 9]'),
#  Text(0.09375, 0.34615384615384615, 'x[4] <= 24.0\ngini = 0.198\nsamples = 27\nvalue = [24, 3]'),
#  Text(0.08333333333333333, 0.2692307692307692, 'x[1] <= 116.5\ngini = 0.142\nsamples = 26\nvalue = [24, 2]'),
#  Text(0.07291666666666667, 0.19230769230769232, 'gini = 0.0\nsamples = 20\nvalue = [20, 0]'),
#  Text(0.09375, 0.19230769230769232, 'x[2] <= 73.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.08333333333333333, 0.11538461538461539, 'x[6] <= 0.418\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.07291666666666667, 0.038461538461538464, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.09375, 0.038461538461538464, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.10416666666666667, 0.11538461538461539, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.10416666666666667, 0.2692307692307692, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13541666666666666, 0.34615384615384615, 'x[1] <= 111.5\ngini = 0.497\nsamples = 13\nvalue = [7, 6]'),
#  Text(0.125, 0.2692307692307692, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.14583333333333334, 0.2692307692307692, 'x[2] <= 72.0\ngini = 0.48\nsamples = 10\nvalue = [4, 6]'),
#  Text(0.13541666666666666, 0.19230769230769232, 'x[2] <= 65.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.125, 0.11538461538461539, 'x[1] <= 123.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.11458333333333333, 0.038461538461538464, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.13541666666666666, 0.038461538461538464, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.14583333333333334, 0.11538461538461539, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.15625, 0.19230769230769232, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.1875, 0.4230769230769231, 'x[3] <= 40.5\ngini = 0.074\nsamples = 52\nvalue = [50, 2]'),
#  Text(0.17708333333333334, 0.34615384615384615, 'gini = 0.0\nsamples = 43\nvalue = [43, 0]'),
#  Text(0.19791666666666666, 0.34615384615384615, 'x[1] <= 110.5\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.1875, 0.2692307692307692, 'x[5] <= 38.65\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.17708333333333334, 0.19230769230769232, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.19791666666666666, 0.19230769230769232, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.20833333333333334, 0.2692307692307692, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.1171875, 0.5769230769230769, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.12760416666666666, 0.6538461538461539, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.24479166666666666, 0.7307692307692307, 'x[2] <= 55.0\ngini = 0.469\nsamples = 48\nvalue = [30, 18]'),
#  Text(0.234375, 0.6538461538461539, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.2552083333333333, 0.6538461538461539, 'x[5] <= 30.3\ngini = 0.422\nsamples = 43\nvalue = [30, 13]'),
#  Text(0.22916666666666666, 0.5769230769230769, 'x[1] <= 129.5\ngini = 0.117\nsamples = 16\nvalue = [15, 1]'),
#  Text(0.21875, 0.5, 'x[5] <= 26.95\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.20833333333333334, 0.4230769230769231, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.22916666666666666, 0.4230769230769231, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.23958333333333334, 0.5, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.28125, 0.5769230769230769, 'x[4] <= 197.0\ngini = 0.494\nsamples = 27\nvalue = [15, 12]'),
#  Text(0.2708333333333333, 0.5, 'x[4] <= 125.0\ngini = 0.496\nsamples = 22\nvalue = [10, 12]'),
#  Text(0.25, 0.4230769230769231, 'x[5] <= 41.1\ngini = 0.459\nsamples = 14\nvalue = [9, 5]'),
#  Text(0.23958333333333334, 0.34615384615384615, 'x[6] <= 1.141\ngini = 0.375\nsamples = 12\nvalue = [9, 3]'),
#  Text(0.22916666666666666, 0.2692307692307692, 'x[0] <= 0.5\ngini = 0.298\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.21875, 0.19230769230769232, 'x[5] <= 33.75\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.20833333333333334, 0.11538461538461539, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.22916666666666666, 0.11538461538461539, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.23958333333333334, 0.19230769230769232, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.25, 0.2692307692307692, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.2604166666666667, 0.34615384615384615, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2916666666666667, 0.4230769230769231, 'x[1] <= 149.0\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.28125, 0.34615384615384615, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.3020833333333333, 0.34615384615384615, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.2916666666666667, 0.5, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.4560546875, 0.8076923076923077, 'x[5] <= 26.95\ngini = 0.487\nsamples = 181\nvalue = [105, 76]'),
#  Text(0.34375, 0.7307692307692307, 'x[2] <= 94.0\ngini = 0.105\nsamples = 36\nvalue = [34, 2]'),
#  Text(0.3229166666666667, 0.6538461538461539, 'x[1] <= 133.0\ngini = 0.057\nsamples = 34\nvalue = [33, 1]'),
#  Text(0.3125, 0.5769230769230769, 'gini = 0.0\nsamples = 28\nvalue = [28, 0]'),
#  Text(0.3333333333333333, 0.5769230769230769, 'x[1] <= 135.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.3229166666666667, 0.5, 'x[7] <= 70.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.3125, 0.4230769230769231, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3333333333333333, 0.4230769230769231, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.34375, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.3645833333333333, 0.6538461538461539, 'x[7] <= 44.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.3541666666666667, 0.5769230769230769, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.375, 0.5769230769230769, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.568359375, 0.7307692307692307, 'x[1] <= 94.5\ngini = 0.5\nsamples = 145\nvalue = [71, 74]'),
#  Text(0.40625, 0.6538461538461539, 'x[1] <= 28.5\ngini = 0.278\nsamples = 24\nvalue = [20, 4]'),
#  Text(0.3958333333333333, 0.5769230769230769, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.4166666666666667, 0.5769230769230769, 'x[0] <= 9.5\ngini = 0.165\nsamples = 22\nvalue = [20, 2]'),
#  Text(0.40625, 0.5, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.4270833333333333, 0.5, 'x[6] <= 0.291\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.4166666666666667, 0.4230769230769231, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.4375, 0.4230769230769231, 'x[4] <= 27.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.4270833333333333, 0.34615384615384615, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.4479166666666667, 0.34615384615384615, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.73046875, 0.6538461538461539, 'x[6] <= 0.528\ngini = 0.488\nsamples = 121\nvalue = [51, 70]'),
#  Text(0.6484375, 0.5769230769230769, 'x[2] <= 83.0\ngini = 0.5\nsamples = 80\nvalue = [40, 40]'),
#  Text(0.5572916666666666, 0.5, 'x[3] <= 26.5\ngini = 0.488\nsamples = 59\nvalue = [25, 34]'),
#  Text(0.5052083333333334, 0.4230769230769231, 'x[1] <= 127.0\ngini = 0.415\nsamples = 34\nvalue = [10, 24]'),
#  Text(0.46875, 0.34615384615384615, 'x[0] <= 8.5\ngini = 0.245\nsamples = 21\nvalue = [3, 18]'),
#  Text(0.4479166666666667, 0.2692307692307692, 'x[4] <= 88.0\ngini = 0.117\nsamples = 16\nvalue = [1, 15]'),
#  Text(0.4375, 0.19230769230769232, 'gini = 0.0\nsamples = 15\nvalue = [0, 15]'),
#  Text(0.4583333333333333, 0.19230769230769232, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.4895833333333333, 0.2692307692307692, 'x[3] <= 12.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.4791666666666667, 0.19230769230769232, 'x[2] <= 67.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.46875, 0.11538461538461539, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4895833333333333, 0.11538461538461539, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5, 0.19230769230769232, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.5416666666666666, 0.34615384615384615, 'x[1] <= 143.5\ngini = 0.497\nsamples = 13\nvalue = [7, 6]'),
#  Text(0.53125, 0.2692307692307692, 'x[0] <= 3.5\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.5208333333333334, 0.19230769230769232, 'x[7] <= 53.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.5104166666666666, 0.11538461538461539, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.53125, 0.11538461538461539, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5416666666666666, 0.19230769230769232, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.5520833333333334, 0.2692307692307692, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.609375, 0.4230769230769231, 'x[5] <= 33.4\ngini = 0.48\nsamples = 25\nvalue = [15, 10]'),
#  Text(0.5833333333333334, 0.34615384615384615, 'x[0] <= 2.5\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.5729166666666666, 0.2692307692307692, 'x[4] <= 161.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5625, 0.19230769230769232, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5833333333333334, 0.19230769230769232, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.59375, 0.2692307692307692, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.6354166666666666, 0.34615384615384615, 'x[1] <= 110.0\ngini = 0.492\nsamples = 16\nvalue = [7, 9]'),
#  Text(0.6145833333333334, 0.2692307692307692, 'x[6] <= 0.315\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.6041666666666666, 0.19230769230769232, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.625, 0.19230769230769232, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.65625, 0.2692307692307692, 'x[4] <= 219.0\ngini = 0.32\nsamples = 10\nvalue = [2, 8]'),
#  Text(0.6458333333333334, 0.19230769230769232, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.6666666666666666, 0.19230769230769232, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.7395833333333334, 0.5, 'x[4] <= 124.0\ngini = 0.408\nsamples = 21\nvalue = [15, 6]'),
#  Text(0.71875, 0.4230769230769231, 'x[5] <= 41.2\ngini = 0.219\nsamples = 16\nvalue = [14, 2]'),
#  Text(0.7083333333333334, 0.34615384615384615, 'x[7] <= 35.5\ngini = 0.124\nsamples = 15\nvalue = [14, 1]'),
#  Text(0.6979166666666666, 0.2692307692307692, 'x[4] <= 44.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.6875, 0.19230769230769232, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7083333333333334, 0.19230769230769232, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.71875, 0.2692307692307692, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.7291666666666666, 0.34615384615384615, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7604166666666666, 0.4230769230769231, 'x[3] <= 19.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.75, 0.34615384615384615, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7708333333333334, 0.34615384615384615, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.8125, 0.5769230769230769, 'x[6] <= 0.676\ngini = 0.393\nsamples = 41\nvalue = [11, 30]'),
#  Text(0.8020833333333334, 0.5, 'gini = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(0.8229166666666666, 0.5, 'x[1] <= 141.0\ngini = 0.483\nsamples = 27\nvalue = [11, 16]'),
#  Text(0.8020833333333334, 0.4230769230769231, 'x[7] <= 31.5\ngini = 0.434\nsamples = 22\nvalue = [7, 15]'),
#  Text(0.7916666666666666, 0.34615384615384615, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8125, 0.34615384615384615, 'x[2] <= 81.0\ngini = 0.375\nsamples = 20\nvalue = [5, 15]'),
#  Text(0.8020833333333334, 0.2692307692307692, 'x[4] <= 120.5\ngini = 0.486\nsamples = 12\nvalue = [5, 7]'),
#  Text(0.78125, 0.19230769230769232, 'x[0] <= 5.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.7708333333333334, 0.11538461538461539, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.7916666666666666, 0.11538461538461539, 'x[2] <= 78.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.78125, 0.038461538461538464, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8020833333333334, 0.038461538461538464, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8229166666666666, 0.19230769230769232, 'x[3] <= 42.5\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.8125, 0.11538461538461539, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.8333333333333334, 0.11538461538461539, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8229166666666666, 0.2692307692307692, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.84375, 0.4230769230769231, 'x[3] <= 42.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.8333333333333334, 0.34615384615384615, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.8541666666666666, 0.34615384615384615, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8984375, 0.8846153846153846, 'x[5] <= 28.7\ngini = 0.232\nsamples = 82\nvalue = [11, 71]'),
#  Text(0.84375, 0.8076923076923077, 'x[5] <= 25.35\ngini = 0.486\nsamples = 12\nvalue = [5, 7]'),
#  Text(0.8333333333333334, 0.7307692307692307, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.8541666666666666, 0.7307692307692307, 'x[6] <= 0.368\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.84375, 0.6538461538461539, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8645833333333334, 0.6538461538461539, 'x[3] <= 16.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.8541666666666666, 0.5769230769230769, 'x[6] <= 0.923\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.84375, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8645833333333334, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.875, 0.5769230769230769, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.953125, 0.8076923076923077, 'x[6] <= 1.428\ngini = 0.157\nsamples = 70\nvalue = [6, 64]'),
#  Text(0.9270833333333334, 0.7307692307692307, 'x[6] <= 0.135\ngini = 0.116\nsamples = 65\nvalue = [4, 61]'),
#  Text(0.90625, 0.6538461538461539, 'x[3] <= 17.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.8958333333333334, 0.5769230769230769, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.9166666666666666, 0.5769230769230769, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.9479166666666666, 0.6538461538461539, 'x[2] <= 69.0\ngini = 0.091\nsamples = 63\nvalue = [3, 60]'),
#  Text(0.9375, 0.5769230769230769, 'x[3] <= 26.5\ngini = 0.291\nsamples = 17\nvalue = [3, 14]'),
#  Text(0.9270833333333334, 0.5, 'x[2] <= 63.0\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(0.9166666666666666, 0.4230769230769231, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.9375, 0.4230769230769231, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.9479166666666666, 0.5, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.9583333333333334, 0.5769230769230769, 'gini = 0.0\nsamples = 46\nvalue = [0, 46]'),
#  Text(0.9791666666666666, 0.7307692307692307, 'x[1] <= 181.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.96875, 0.6538461538461539, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.9895833333333334, 0.6538461538461539, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]')]

# %%
DTC=DecisionTreeClassifier(max_depth=2)
DTC.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(DTC,filled=True)
# Out:
# [Text(0.5, 0.8333333333333334, 'x[1] <= 154.5\ngini = 0.457\nsamples = 514\nvalue = [332, 182]'),
#  Text(0.25, 0.5, 'x[7] <= 30.5\ngini = 0.382\nsamples = 432\nvalue = [321, 111]'),
#  Text(0.125, 0.16666666666666666, 'gini = 0.24\nsamples = 251\nvalue = [216, 35]'),
#  Text(0.375, 0.16666666666666666, 'gini = 0.487\nsamples = 181\nvalue = [105, 76]'),
#  Text(0.75, 0.5, 'x[5] <= 28.7\ngini = 0.232\nsamples = 82\nvalue = [11, 71]'),
#  Text(0.625, 0.16666666666666666, 'gini = 0.486\nsamples = 12\nvalue = [5, 7]'),
#  Text(0.875, 0.16666666666666666, 'gini = 0.157\nsamples = 70\nvalue = [6, 64]')]

# %%
y_pred=DTC.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,precision_score,f1_score,recall_score

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.7165354330708661

# %%
precision_score(y_pred,y_test)
# Out:
# 0.313953488372093

# %%
f1_score(y_pred,y_test)
# Out:
# 0.42857142857142855

# %%
recall_score(y_pred,y_test)
# Out:
# 0.675
